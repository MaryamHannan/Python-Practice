# %%
# pandas tutorial 
import pandas as pd 
import numpy as np

# %%
data={
    "name" : ['fiza','ali','aroba'],
    "class" :[1,4,8],
    "rollno" : [32,56,12] 
}

# %%
stu=pd.DataFrame(data)

# %%
stu
# Out:
#     name  class  rollno
# 0   fiza      1      32
# 1    ali      4      56
# 2  aroba      8      12

# %%
data=pd.read_csv("C:/Users/moizr/Downloads/SuperStore_Sales_Dataset.csv")

# %%
data
# Out:
#       Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date  \
# 0                 4918  CA-2019-160304  01-01-2019  07-01-2019
# 1                 4919  CA-2019-160304  02-01-2019  07-01-2019
# 2                 4920  CA-2019-160304  02-01-2019  07-01-2019
# 3                 3074  CA-2019-125206  03-01-2019  05-01-2019
# 4                 8604  US-2019-116365  03-01-2019  08-01-2019
# ...                ...             ...         ...         ...
# 5896               907  CA-2020-143259  30-12-2020  03-01-2021
# 5897              1297  CA-2020-115427  30-12-2020  03-01-2021
# 5898              5092  CA-2020-156720  30-12-2020  03-01-2021
# 5899               909  CA-2020-143259  30-12-2020  03-01-2021
# 5900              5093  CA-2020-151450  31-12-2020  04-01-2021
#
#            Ship Mode Customer ID      Customer Name    Segment        Country  \
# 0     Standard Class    BM-11575      Brendan Murry  Corporate  United States
# ...

# %%
data =pd.read_excel("C:/Users/moizr/Downloads/Vrinda Store Data Analysis (1).xlsx")

# %%
data
# Out:
#        index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097      M   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097      M   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295      M   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498      M   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875      M   36 2022-01-06  Delivered
#
# ...

# %%
data.head()
# Out:
#    index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0      1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1      2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2      3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3      4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4      5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
#
#   Channel                       SKU Category Size Qty currency  Amount  \
# 0   Myntra  JNE1233-BLUE-KR-031-XXL    kurta  XXL   1      INR     376
# 1     Ajio           SET414-KR-NP-L      Set    L   1      INR    1449
# 2   Myntra           SET261-KR-PP-S      Set    S   1      INR     453
# 3   Amazon           SET110-KR-PP-M      Set    M   1      INR     729
# 4   Myntra         JNE2294-KR-A-XXL    kurta  XXL   1      INR     544
#
#    ship-city   ship-state  ship-postal-code ship-country    B2B
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31047 entries, 0 to 31046
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             31047 non-null  int64
#  1   Order ID          31047 non-null  object
#  2   Cust ID           31047 non-null  int64
#  3   Gender            31047 non-null  object
#  4   Age               31047 non-null  int64
#  5   Date              31047 non-null  datetime64[ns]
#  6   Status            31047 non-null  object
#  7   Channel           31047 non-null  object
#  8   SKU               31047 non-null  object
#  9   Category          31047 non-null  object
#  10  Size              31047 non-null  object
#  11  Qty               31047 non-null  object
#  12  currency          31047 non-null  object
#  13  Amount            31047 non-null  int64
#  14  ship-city         31047 non-null  object
#  15  ship-state        31047 non-null  object
# ...

# %%
data.describe()
# Out:
#              index       Cust ID           Age                           Date  \
# count  31047.00000  3.104700e+04  31047.000000                          31047
# mean   15524.00000  4.936824e+06     39.496570  2022-06-15 06:41:39.719779584
# min        1.00000  8.950000e+02     18.000000            2022-01-04 00:00:00
# 25%     7762.50000  2.416471e+06     28.000000            2022-03-06 00:00:00
# 50%    15524.00000  4.909885e+06     37.000000            2022-06-06 00:00:00
# 75%    23285.50000  7.454182e+06     47.000000            2022-09-06 00:00:00
# max    31047.00000  9.999233e+06     78.000000            2022-12-06 00:00:00
# std     8962.64124  2.900678e+06     15.117233                            NaN
#
#              Amount  ship-postal-code
# count  31047.000000      31047.000000
# mean     682.074822     460474.587206
# min      229.000000     110001.000000
# 25%      486.000000     313001.000000
# 50%      646.000000     500028.000000
# ...

# %%
data.isnull()
# Out:
#        index  Order ID  Cust ID  Gender    Age   Date  Status  Channel   \
# 0      False     False    False   False  False  False   False     False
# 1      False     False    False   False  False  False   False     False
# 2      False     False    False   False  False  False   False     False
# 3      False     False    False   False  False  False   False     False
# 4      False     False    False   False  False  False   False     False
# ...      ...       ...      ...     ...    ...    ...     ...       ...
# 31042  False     False    False   False  False  False   False     False
# 31043  False     False    False   False  False  False   False     False
# 31044  False     False    False   False  False  False   False     False
# 31045  False     False    False   False  False  False   False     False
# 31046  False     False    False   False  False  False   False     False
#
#          SKU  Category   Size    Qty  currency  Amount  ship-city  ship-state  \
# ...

# %%
data.isnull().sum()
# Out:
# index               0
# Order ID            0
# Cust ID             0
# Gender              0
# Age                 0
# Date                0
# Status              0
# Channel             0
# SKU                 0
# Category            0
# Size                0
# Qty                 0
# currency            0
# Amount              0
# ship-city           0
# ship-state          0
# ship-postal-code    0
# ship-country        0
# B2B                 0
# dtype: int64

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31042    False
# 31043    False
# 31044    False
# 31045    False
# 31046    False
# Length: 31047, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#        index             Order ID  Cust ID Gender  Age       Date     Status  \
# 0          1  171-1029312-3038738  1029312  Women   44 2022-12-04  Delivered
# 1          2  405-2183842-2225946  2183842  Women   29 2022-12-04  Delivered
# 2          3  171-1641533-8921966  1641533  Women   67 2022-12-04  Delivered
# 3          4  404-7490807-6300351  7490807  Women   20 2022-12-04  Delivered
# 4          5  403-9293516-4577154  9293516  Women   62 2022-12-04  Delivered
# ...      ...                  ...      ...    ...  ...        ...        ...
# 31042  31043  405-4724097-1016369  4724097      M   60 2022-01-06  Delivered
# 31043  31044  405-4724097-1016369  4724097      M   34 2022-01-06  Delivered
# 31044  31045  408-3572295-5992330  3572295      M   29 2022-01-06  Delivered
# 31045  31046  405-1423498-9705162  1423498      M   46 2022-01-06  Delivered
# 31046  31047  408-4694875-8249153  4694875      M   36 2022-01-06  Delivered
#
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31042    False
# 31043    False
# 31044    False
# 31045    False
# 31046    False
# Length: 31047, dtype: bool

# %%
sales=pd.read_csv("C:/Users/moizr/Downloads/WalmartSalesData.csv")

# %%
sales
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
sales.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
sales.duplicated().sum()
# Out:
# 0

# %%
sales.drop_duplicates("Invoice ID")
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
student=pd.read_excel("C:/Users/moizr/OneDrive/Desktop/student.xlsx")

# %%
student
# Out:
#     Unnamed: 0  Unnamed: 1  stu_id stu_name  age  stu_class   final_test  \
# 0          NaN         NaN       1   subham    3           1          98
# 1          NaN         NaN       2     mala   12           7          96
# 2          NaN         NaN       8      ali   12           8          78
# 3          NaN         NaN       4     gina   12           7          45
# 4          NaN         NaN       5     bina   13           8          45
# 5          NaN         NaN       6     nala   15          11          98
# 6          NaN         NaN       7   subhan    3           1          98
# 7          NaN         NaN       8    alina   12           8          78
# 8          NaN         NaN       8   zunair   12           7          45
# 9          NaN         NaN      10    nimra   13           8          45
# 10         NaN         NaN      11    naila   15          11          98
# 11         NaN         NaN      12   fareed    3           1          98
#
# ...

# %%
student.drop_duplicates("stu_id")
# Out:
#     Unnamed: 0  Unnamed: 1  stu_id stu_name  age  stu_class   final_test  \
# 0          NaN         NaN       1   subham    3           1          98
# 1          NaN         NaN       2     mala   12           7          96
# 2          NaN         NaN       8      ali   12           8          78
# 3          NaN         NaN       4     gina   12           7          45
# 4          NaN         NaN       5     bina   13           8          45
# 5          NaN         NaN       6     nala   15          11          98
# 6          NaN         NaN       7   subhan    3           1          98
# 9          NaN         NaN      10    nimra   13           8          45
# 10         NaN         NaN      11    naila   15          11          98
# 11         NaN         NaN      12   fareed    3           1          98
#
#                email
# 0   subham@gmail.com
# 1     mala@gmail.com
# 2      ali@gmail.com
# 3     gina@gmail.com
# 4     bina@gmail.com
# 5     nala@gmail.com
# ...

# %%
student['stu_id'].duplicated().sum()
# Out:
# 2

# %%
student.isnull().sum()
# Out:
# Unnamed: 0    12
# Unnamed: 1    12
# stu_id         0
# stu_name       0
# age            0
# stu_class      0
# final_test     0
# email          0
# dtype: int64

# %%
student.dropna()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Unnamed: 1, stu_id, stu_name, age, stu_class , final_test, email]
# Index: []

# %%
student
# Out:
#     Unnamed: 0  Unnamed: 1  stu_id stu_name  age  stu_class   final_test  \
# 0          NaN         NaN       1   subham    3           1          98
# 1          NaN         NaN       2     mala   12           7          96
# 2          NaN         NaN       8      ali   12           8          78
# 3          NaN         NaN       4     gina   12           7          45
# 4          NaN         NaN       5     bina   13           8          45
# 5          NaN         NaN       6     nala   15          11          98
# 6          NaN         NaN       7   subhan    3           1          98
# 7          NaN         NaN       8    alina   12           8          78
# 8          NaN         NaN       8   zunair   12           7          45
# 9          NaN         NaN      10    nimra   13           8          45
# 10         NaN         NaN      11    naila   15          11          98
# 11         NaN         NaN      12   fareed    3           1          98
#
# ...

# %%
student.replace(np.nan,'hi')
# Out:
#    Unnamed: 0 Unnamed: 1  stu_id stu_name  age  stu_class   final_test  \
# 0          hi         hi       1   subham    3           1          98
# 1          hi         hi       2     mala   12           7          96
# 2          hi         hi       8      ali   12           8          78
# 3          hi         hi       4     gina   12           7          45
# 4          hi         hi       5     bina   13           8          45
# 5          hi         hi       6     nala   15          11          98
# 6          hi         hi       7   subhan    3           1          98
# 7          hi         hi       8    alina   12           8          78
# 8          hi         hi       8   zunair   12           7          45
# 9          hi         hi      10    nimra   13           8          45
# 10         hi         hi      11    naila   15          11          98
# 11         hi         hi      12   fareed    3           1          98
#
#                email
# 0   subham@gmail.com
# ...

# %%
student.iloc[: ,[0,1]]
# Out:
#     Unnamed: 0  Unnamed: 1
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN

# %%
student.dropna(how='all',axis=1,inplace=True)

# %%
student
# Out:
#     stu_id stu_name  age  stu_class   final_test             email
# 0        1   subham    3           1          98  subham@gmail.com
# 1        2     mala   12           7          96    mala@gmail.com
# 2        8      ali   12           8          78     ali@gmail.com
# 3        4     gina   12           7          45    gina@gmail.com
# 4        5     bina   13           8          45    bina@gmail.com
# 5        6     nala   15          11          98    nala@gmail.com
# 6        7   subhan    3           1          98  subhan@gmail.com
# 7        8    alina   12           8          78   alina@gmail.com
# 8        8   zunair   12           7          45  zunair@gmail.com
# 9       10    nimra   13           8          45   nimra@gmail.com
# 10      11    naila   15          11          98   naila@gmail.com
# 11      12   fareed    3           1          98  fareed@gmail.com

# %%
student['stu_id'].duplicated().sum()
# Out:
# 2

# %%
student.drop_duplicates("stu_id")
# Out:
#     stu_id stu_name  age  stu_class   final_test             email
# 0        1   subham    3           1          98  subham@gmail.com
# 1        2     mala   12           7          96    mala@gmail.com
# 2        8      ali   12           8          78     ali@gmail.com
# 3        4     gina   12           7          45    gina@gmail.com
# 4        5     bina   13           8          45    bina@gmail.com
# 5        6     nala   15          11          98    nala@gmail.com
# 6        7   subhan    3           1          98  subhan@gmail.com
# 9       10    nimra   13           8          45   nimra@gmail.com
# 10      11    naila   15          11          98   naila@gmail.com
# 11      12   fareed    3           1          98  fareed@gmail.com

# %%
student['final_test'].mean()
# Out:
# 76.83333333333333

# %%
student2=pd.read_excel("C:/Users/moizr/OneDrive/Desktop/student.xlsx")

# %%
student2
# Out:
#     stu_id stu_name   age  stu_class   final_test             email
# 0        1   subham   3.0         1.0        98.0  subham@gmail.com
# 1        2     mala  12.0         7.0        96.0    mala@gmail.com
# 2        8      ali  12.0         8.0        78.0     ali@gmail.com
# 3        4     gina  12.0         7.0        45.0    gina@gmail.com
# 4        5     bina  13.0         NaN        45.0    bina@gmail.com
# 5        6     nala  15.0        11.0        98.0    nala@gmail.com
# 6        7   subhan   NaN         1.0        98.0  subhan@gmail.com
# 7        8    alina  12.0         8.0        78.0   alina@gmail.com
# 8        8   zunair  12.0         7.0         NaN  zunair@gmail.com
# 9       10    nimra  13.0         8.0        45.0   nimra@gmail.com
# 10      11    naila  15.0        11.0        98.0   naila@gmail.com
# 11      12   fareed   3.0         1.0        98.0  fareed@gmail.com

# %%
student2.ffill()
# Out:
#     stu_id stu_name   age  stu_class   final_test             email
# 0        1   subham   3.0         1.0        98.0  subham@gmail.com
# 1        2     mala  12.0         7.0        96.0    mala@gmail.com
# 2        8      ali  12.0         8.0        78.0     ali@gmail.com
# 3        4     gina  12.0         7.0        45.0    gina@gmail.com
# 4        5     bina  13.0         7.0        45.0    bina@gmail.com
# 5        6     nala  15.0        11.0        98.0    nala@gmail.com
# 6        7   subhan  15.0         1.0        98.0  subhan@gmail.com
# 7        8    alina  12.0         8.0        78.0   alina@gmail.com
# 8        8   zunair  12.0         7.0        78.0  zunair@gmail.com
# 9       10    nimra  13.0         8.0        45.0   nimra@gmail.com
# 10      11    naila  15.0        11.0        98.0   naila@gmail.com
# 11      12   fareed   3.0         1.0        98.0  fareed@gmail.com

# %%
esd=pd.read_excel("C:/Users/moizr/Downloads/ESD.xlsx")

# %%
esd
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
esd.loc[(esd["Bonus %"]== 0),"getbonus"]="nobonus" 
esd.loc[(esd["Bonus %"]>0), "getbonus"]="bonus"

# %%
esd
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
esd.head()
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date getbonus
# 0     0.15  United States    Seattle 2021-10-16    bonus
# ...

# %%
stu=pd.read_excel("C:/Users/moizr/OneDrive/Desktop/student.xlsx")

# %%
stu
# Out:
#     stu_id firstname lastname   age  stu_class   final_test             email
# 0        1    subham      ali   3.0         1.0        98.0  subham@gmail.com
# 1        2      mala     gira  12.0         7.0        96.0    mala@gmail.com
# 2        8       ali      rao  12.0         8.0        78.0     ali@gmail.com
# 3        4      gina       rj  12.0         7.0        45.0    gina@gmail.com
# 4        5      bina    saeed  13.0         NaN        45.0    bina@gmail.com
# 5        6      nala     khan  15.0        11.0        98.0    nala@gmail.com
# 6        7    subhan     geet   NaN         1.0        98.0  subhan@gmail.com
# 7        8     alina     raza  12.0         8.0        78.0   alina@gmail.com
# 8        8    zunair      raj  12.0         7.0         NaN  zunair@gmail.com
# 9       10     nimra     khan  13.0         8.0        45.0   nimra@gmail.com
# 10      11     naila      rao  15.0        11.0        98.0   naila@gmail.com
# ...

# %%
stu["Full_Name"]=stu["firstname"].str.capitalize()+" "+stu["lastname"]

# %%
stu
# Out:
#     stu_id firstname lastname   age  stu_class   final_test             email  \
# 0        1    subham      ali   3.0         1.0        98.0  subham@gmail.com
# 1        2      mala     gira  12.0         7.0        96.0    mala@gmail.com
# 2        8       ali      rao  12.0         8.0        78.0     ali@gmail.com
# 3        4      gina       rj  12.0         7.0        45.0    gina@gmail.com
# 4        5      bina    saeed  13.0         NaN        45.0    bina@gmail.com
# 5        6      nala     khan  15.0        11.0        98.0    nala@gmail.com
# 6        7    subhan     geet   NaN         1.0        98.0  subhan@gmail.com
# 7        8     alina     raza  12.0         8.0        78.0   alina@gmail.com
# 8        8    zunair      raj  12.0         7.0         NaN  zunair@gmail.com
# 9       10     nimra     khan  13.0         8.0        45.0   nimra@gmail.com
# 10      11     naila      rao  15.0        11.0        98.0   naila@gmail.com
# ...

# %%
stu["Prize"]=(stu["final_test"]/100)*20

# %%
stu
# Out:
#     stu_id firstname lastname   age  stu_class   final_test             email  \
# 0        1    subham      ali   3.0         1.0        98.0  subham@gmail.com
# 1        2      mala     gira  12.0         7.0        96.0    mala@gmail.com
# 2        8       ali      rao  12.0         8.0        78.0     ali@gmail.com
# 3        4      gina       rj  12.0         7.0        45.0    gina@gmail.com
# 4        5      bina    saeed  13.0         NaN        45.0    bina@gmail.com
# 5        6      nala     khan  15.0        11.0        98.0    nala@gmail.com
# 6        7    subhan     geet   NaN         1.0        98.0  subhan@gmail.com
# 7        8     alina     raza  12.0         8.0        78.0   alina@gmail.com
# 8        8    zunair      raj  12.0         7.0         NaN  zunair@gmail.com
# 9       10     nimra     khan  13.0         8.0        45.0   nimra@gmail.com
# 10      11     naila      rao  15.0        11.0        98.0   naila@gmail.com
# ...

# %%
data={
    "Months" : ["January","February","March","April","May","June"]
}
a=pd.DataFrame(data)
a
# Out:
#      Months
# 0   January
# 1  February
# 2     March
# 3     April
# 4       May
# 5      June

# %%
def extract(value):
    return value[0:3]
a["short_months"]=a["Months"].map(extract)

# %%
a
# Out:
#      Months short_months
# 0   January          Jan
# 1  February          Feb
# 2     March          Mar
# 3     April          Apr
# 4       May          May
# 5      June          Jun

# %%
esd=pd.read_excel("C:/Users/moizr/Downloads/ESD.xlsx")

# %%
esd
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
gp=esd.groupby(['Job Title','Gender']).agg({'EEID':'count'})

# %%
gp
# Out:
#                                EEID
# Job Title              Gender
# Account Representative Female    15
#                        Male       6
# Analyst                Female    31
#                        Male      20
# Analyst II             Female    21
# ...                             ...
# Technical Architect    Male       8
# Test Engineer          Female     7
#                        Male       5
# Vice President         Female    50
#                        Male      55
#
# [66 rows x 1 columns]

# %%
gp1=esd.groupby(["Department","Business Unit","Gender"]).agg({"EEID" : "count"})

# %%
gp1
# Out:
#                                                EEID
# Department      Business Unit          Gender
# Accounting      Corporate              Female    18
#                                        Male       3
#                 Manufacturing          Female    14
#                                        Male      14
#                 Research & Development Female     8
#                                        Male      10
#                 Speciality Products    Female    13
#                                        Male      16
# Engineering     Corporate              Female    20
#                                        Male      15
#                 Manufacturing          Female    15
#                                        Male      18
#                 Research & Development Female    27
#                                        Male      16
#                 Speciality Products    Female    18
#                                        Male      29
# ...

# %%
gp2=esd.groupby("Ethnicity").agg({"Annual Salary":"mean"})

# %%
gp2
# Out:
#            Annual Salary
# Ethnicity
# Asian      117627.972772
# Black      109021.972973
# Caucasian  109345.022140
# Latino     111536.003984

# %%
Data1={
    "Emp ID" : [101,102,103,104,105,106],
    "Name":['Raj','Ram','Rao','Raza',"Sami",'Rana'],
    "Age":[24,76,45,31,90,67]
}
Data2={
     "Emp ID" : [101,102,103,104,105,106],
     "Salary" :["25k","67k","87k","61k",'250k','750k']
}
df1=pd.DataFrame(Data1)
df2=pd.DataFrame(Data2)
pd.merge(df1,df2,on="Emp ID")
# Out:
#    Emp ID  Name  Age Salary
# 0     101   Raj   24    25k
# 1     102   Ram   76    67k
# 2     103   Rao   45    87k
# 3     104  Raza   31    61k
# 4     105  Sami   90   250k
# 5     106  Rana   67   750k

# %%
Data1={
    "Emp ID" : [101,102,103,104,109,106],
    "Name":['Raj','Ram','Rao','Raza',"Sami",'Rana'],
    "Age":[24,76,45,31,90,67]
}
Data2={
     "Emp ID" : [101,102,108,104,105,107],
     "Salary" :["25k","67k","87k","61k",'250k','750k']
}
df1=pd.DataFrame(Data1)
df2=pd.DataFrame(Data2)
pd.merge(df1,df2,on="Emp ID")
# Out:
#    Emp ID  Name  Age Salary
# 0     101   Raj   24    25k
# 1     102   Ram   76    67k
# 2     104  Raza   31    61k

# %%
Data1={
    "Emp ID" : [101,102,103,104,109,106],
    "Name":['Raj','Ram','Rao','Raza',"Sami",'Rana'],
    "Age":[24,76,45,31,90,67]
}
Data2={
     "Emp ID" : [101,102,108,104,105,107],
     "Salary" :["25k","67k","87k","61k",'250k','750k']
}
df1=pd.DataFrame(Data1)
df2=pd.DataFrame(Data2)
pd.merge(df1,df2,on="Emp ID" ,how='left')
# Out:
#    Emp ID  Name  Age Salary
# 0     101   Raj   24    25k
# 1     102   Ram   76    67k
# 2     103   Rao   45    NaN
# 3     104  Raza   31    61k
# 4     109  Sami   90    NaN
# 5     106  Rana   67    NaN

# %%
Data1={
    "Emp ID" : [101,102,103,104,109,106],
    "Name":['Raj','Ram','Rao','Raza',"Sami",'Rana'],
    "Age":[24,76,45,31,90,67]
}
Data2={
     "Emp ID" : [101,102,108,104,105,107],
     "Salary" :["25k","67k","87k","61k",'250k','750k']
}
df1=pd.DataFrame(Data1)
df2=pd.DataFrame(Data2)
pd.merge(df1,df2,on="Emp ID" ,how='right')
# Out:
#    Emp ID  Name   Age Salary
# 0     101   Raj  24.0    25k
# 1     102   Ram  76.0    67k
# 2     108   NaN   NaN    87k
# 3     104  Raza  31.0    61k
# 4     105   NaN   NaN   250k
# 5     107   NaN   NaN   750k

# %%
Data11={
    "Emp ID" : [101,102,103,104,109,106],
    "Name":['Raj','Ram','Rao','Raza',"Sami",'Rana'],
    "Age":[24,76,45,31,90,67]
}
Data21={
     "Emp ID" : [107,108,109,110,111,112],
     "Name":['iraj','irma','ali','ahsan',"zara",'Raja'],
    "Age":[24,76,45,31,90,67]
}

# %%
df11=pd.DataFrame(Data11)
df22=pd.DataFrame(Data21)

# %%
pd.concat([df11,df22])
# Out:
#    Emp ID   Name  Age
# 0     101    Raj   24
# 1     102    Ram   76
# 2     103    Rao   45
# 3     104   Raza   31
# 4     109   Sami   90
# 5     106   Rana   67
# 0     107   iraj   24
# 1     108   irma   76
# 2     109    ali   45
# 3     110  ahsan   31
# 4     111   zara   90
# 5     112   Raja   67

# %%
dict1={
    "fruits" :['mango','orange','papaya','banana','kiwi'],
    "price" :[340,245,23,432,54],
    "quantity":[20,67,89,21,23]
    
}
dt=pd.DataFrame(dict1)

# %%
dt2=dt.copy()

# %%
dt2.loc[0,'price']=350
dt2.loc[1,'price']=270
dt2.loc[0,"quantity"]=50
dt2.loc[1,"quantity"]=10

# %%
dt2
# Out:
#    fruits  price  quantity
# 0   mango    350        50
# 1  orange    270        10
# 2  papaya     23        89
# 3  banana    432        21
# 4    kiwi     54        23

# %%
dt.compare(dt2)
# Out:
#    price        quantity
#     self  other     self other
# 0  340.0  350.0     20.0  50.0
# 1  245.0  270.0     67.0  10.0

# %%
device={
    "key":['k1','k2','k1','k2'],
    "Names":['john','ben','peter','sunny'],
    "Houses":['red','blue','green','red']
}
device1=pd.DataFrame(device)

# %%
device1
# Out:
#   key  Names Houses
# 0  k1   john    red
# 1  k2    ben   blue
# 2  k1  peter  green
# 3  k2  sunny    red

# %%
device1.pivot(index="key", columns="Names", values="Houses")
# Out:
# Names   ben john  peter sunny
# key
# k1      NaN  red  green   NaN
# k2     blue  NaN    NaN   red

# %%
melti={
    
    "Names":['john','ben','peter','sunny'],
    "Houses":['red','blue','green','red'],
     "Age":[24,76,45,31]
}
melt1=pd.DataFrame(melti)

# %%
pd.melt(melt1,id_vars=['Names'],value_vars=['Houses'])
# Out:
#    Names variable  value
# 0   john   Houses    red
# 1    ben   Houses   blue
# 2  peter   Houses  green
# 3  sunny   Houses    red
